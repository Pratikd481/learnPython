# %% [markdown]
# # Dropna Fillna

# %%
import pandas as pd

csv = pd.read_csv('test.csv')
csv.head(10)
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F       s          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12         NaN        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F     NaN          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
# 5      BDCQ.SEA1AA  2012.09     79261.0        NaN      F  Number          0
# 6      BDCQ.SEA1AA  2012.12         NaN        NaN      F  Number          0
# 7      BDCQ.SEA1AA  2013.03     91571.0        NaN      F  Number          0
# 8      BDCQ.SEA1AA  2013.06     81687.0        NaN      F  Number          0
# 9      BDCQ.SEA1AA  2013.09     81471.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# ...

# %%
csv.dropna(axis=1, how='any', inplace=True)

csv.to_csv('new.csv',index=False)
csv.head(10)
# Out:
#   Series_reference   Period STATUS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06      F          0
# 1      BDCQ.SEA1AA  2011.09      F          0
# 2      BDCQ.SEA1AA  2011.12      F          0
# 3      BDCQ.SEA1AA  2012.03      F          0
# 4      BDCQ.SEA1AA  2012.06      F          0
# 5      BDCQ.SEA1AA  2012.09      F          0
# 6      BDCQ.SEA1AA  2012.12      F          0
# 7      BDCQ.SEA1AA  2013.03      F          0
# 8      BDCQ.SEA1AA  2013.06      F          0
# 9      BDCQ.SEA1AA  2013.09      F          0
#
#                              Group Series_title_1  \
# 0  Industry by employment variable    Filled jobs
# 1  Industry by employment variable    Filled jobs
# 2  Industry by employment variable    Filled jobs
# 3  Industry by employment variable    Filled jobs
# 4  Industry by employment variable    Filled jobs
# 5  Industry by employment variable    Filled jobs
# 6  Industry by employment variable    Filled jobs
# ...

# %%
import pandas as pd

csv = pd.read_csv('new.csv')
csv.fillna("python", inplace=True)
csv
# Out:
#       Series_reference   Period STATUS  Magnitude  \
# 0          BDCQ.SEA1AA  2011.06      F          0
# 1          BDCQ.SEA1AA  2011.09      F          0
# 2          BDCQ.SEA1AA  2011.12      F          0
# 3          BDCQ.SEA1AA  2012.03      F          0
# 4          BDCQ.SEA1AA  2012.06      F          0
# ...                ...      ...    ...        ...
# 23732    BDCQ.SEE3999A  2017.06      C          0
# 23733    BDCQ.SEE3999A  2017.09      C          0
# 23734    BDCQ.SEE3999A  2017.12      C          0
# 23735    BDCQ.SEE3999A  2018.03      C          0
# 23736    BDCQ.SEE3999A  2018.06      C          0
#
#                                               Group  \
# 0                   Industry by employment variable
# 1                   Industry by employment variable
# 2                   Industry by employment variable
# 3                   Industry by employment variable
# 4                   Industry by employment variable
# ...
